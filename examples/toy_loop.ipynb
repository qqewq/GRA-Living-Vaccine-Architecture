# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd()))
from sim.engine import main as sim_main
from ai.designer import evolve_population

print("=== Simulation ===")
sim_main()
print("\n=== Evolution ===")
best = evolve_population(pop_size=8, generations=3)
print("Best agent:", best)
